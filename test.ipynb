# %%
# !pip install zarr
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.6/319.6 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 61.2 MB/s eta 0:00:0000:0100:01
# ...

# %%
import xarray as xr


ds = xr.open_dataset("/Users/cindyli/GitHub/weatherloo-internal/data/hrrr/waterloo_janfeb_2026_subset.zarr")

ds
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_326/2070483079.py in <cell line: 0>()
#       2
#       3
# ----> 4 ds = xr.open_dataset("/Users/cindyli/GitHub/weatherloo-internal/data/hrrr/waterloo_janfeb_2026_subset.zarr")
#       5
#       6 ds
#
# /usr/local/lib/python3.12/dist-packages/xarray/backends/api.py in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     585
#     586     if engine is None:
# --> 587         engine = plugins.guess_engine(filename_or_obj)
#     588
#     589     if from_array_kwargs is None:
#
# ...
